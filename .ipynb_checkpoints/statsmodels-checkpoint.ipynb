# %%
import os

import import_ipynb
import starting_out

# data frame manipulation
import numpy as np
import pandas as pd
from collections import defaultdict

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# statistics
import scipy as sp
from scipy import stats
import statsmodels
import statsmodels.api as sm
from statsmodels.regression.linear_model import OLS
os.chdir('C:/Users/jsbae/410project')

# %%
os.chdir('C:/Users/jsbae/410project/data')
df = pd.DataFrame(pd.read_csv('Life Expectancy Data.csv'))

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
# df = starting_out.scale_data(starting_out.clean_data(df))

y = df.Life_Expectancy
X = df.drop(columns=['Life_Expectancy'])

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

X_train = sm.add_constant(X_train)
print(X_train)
# Out:
#       const      Year  Adult_Mortality  Infant_Deaths   Alcohol  \
# 521     1.0 -0.329222        -0.876360      -0.112835 -0.766810
# 971     1.0 -0.329222         0.993626      -0.231573 -0.412334
# 299     1.0 -0.762774         0.792119      -0.248536 -0.914721
# 1214    1.0 -0.979550         0.195658       1.210248 -1.146788
# 2742    1.0 -0.979550         0.735697      -0.206129  0.350173
# ...     ...       ...              ...            ...       ...
# 2008    1.0  1.404986        -0.320200      -0.189167 -1.156989
# 2034    1.0 -0.762774         0.429406       0.302749 -0.024705
# 2237    1.0  0.754658        -0.586190      -0.189167 -1.136587
# 1368    1.0  0.321106         1.227375       0.268824 -0.685204
# 1168    1.0 -1.413102         0.163417      -0.248536  2.201610
#
#       Percentage_Exp  HepatitisB   Measles       BMI  Under_Five_Deaths  \
# 521        -0.347836    0.390460 -0.210774 -0.992434          -0.099962
# 971        -0.371433    0.520934 -0.211036 -0.846939          -0.224636
# 299        -0.370131    0.259986 -0.210774 -1.117861          -0.255805
# 1214       -0.367176   -0.827298  1.922093 -1.047622           1.078208
# 2742       -0.360755   -0.261910 -0.175188  0.868896          -0.224636
# ...              ...         ...       ...       ...                ...
# 2008        0.118475    0.216495 -0.211036  0.828760          -0.199701
# 2034       -0.364691   -1.523160  0.052803 -0.942263           0.274060
# 2237       -0.284103    0.651408 -0.179462  1.320432          -0.205935
# 1368       -0.367837    0.216495 -0.104802 -1.002468           0.305229
# 1168       -0.367609    0.390460 -0.209291  0.914050          -0.255805
#
#          Polio   Tot_Exp  Diphtheria  HIV/AIDS       GDP  Population  \
# 521  -1.524525 -0.805753   -1.327319  1.626556 -0.471167   -0.181605
# 971   0.487187 -0.168349    0.533026  0.247768 -0.364409   -0.163743
# 299  -3.151015 -0.630779    0.279342 -0.284051 -0.482466   -0.188224
# 1214 -3.193818 -1.413994   -0.481708 -0.323445 -0.484938    0.227988
# 2742  0.701199  0.419063    0.617587 -0.165869 -0.486147   -0.100893
# ...        ...       ...         ...       ...       ...         ...
# 2008 -0.197651 -0.189179    0.237062 -0.323445 -0.009026   -0.115851
# 2034  0.101965 -1.122372    0.237062 -0.323445 -0.483826    1.378323
# 2237  0.658396 -0.980726    0.659867 -0.323445 -0.318465   -0.163743
# 1368  0.273175 -0.730764    0.237062  0.641707 -0.490337   -0.181569
# 1168  0.701199  0.494051    0.702148 -0.323445 -0.457614   -0.167427
#
#       thinness_1to19_years  thinness_5to9_years  Income_Comp_Of_Resources  \
# 521               1.086708             1.058586                 -1.498561
# 971               0.950247             0.902514                 -1.050009
# 299               2.997157             3.109827                 -3.073366
# 1214             -0.664537             1.370732                 -0.084649
# 2742             -0.459846            -0.435252                  0.295645
# ...                    ...                  ...                       ...
# 2008             -0.846485            -0.836582                  0.510170
# 2034             -0.869228             1.080883                  0.027489
# 2237              0.586352             0.568072                  0.846583
# 1368              0.768299             0.724145                 -0.567329
# 1168             -0.596307            -0.591325                  0.675939
#
#       Schooling
# 521   -1.840920
# 971   -1.197653
# 299   -0.983230
# 1214  -0.370595
# 2742   0.701518
# ...         ...
# 2008   0.425832
# 2034  -0.125540
# 2237   0.578991
# 1368  -0.401226
# 1168   0.670886
#
# [2350 rows x 20 columns]

# %%
ols_model = sm.OLS(y_train, X_train)
# elastic_model = ols_model.fit_regularized(method='elastic_net')
# sqt_lasso_model = ols_model.fit_regularized(method='sqrt_lasso')

ols_results = ols_model.fit()
# sqt_lasso_results = sqt_lasso_model.fit(y, X)
# elastic_results = statsmodels.base.elastic_net.RegularizedResults(elastic_model, X)
# Out:
# const                      -0.000379
# Year                       -0.004029
# Adult_Mortality            -0.268114
# Infant_Deaths               1.228382
# Alcohol                     0.050303
# Percentage_Exp              0.008488
# HepatitisB                 -0.037915
# Measles                    -0.027685
# BMI                         0.093712
# Under_Five_Deaths          -1.245644
# Polio                       0.064613
# Tot_Exp                     0.031546
# Diphtheria                  0.104742
# HIV/AIDS                   -0.249508
# GDP                         0.077874
# Population                  0.000427
# thinness_1to19_years       -0.034066
# thinness_5to9_years        -0.000950
# Income_Comp_Of_Resources    0.133202
# Schooling                   0.216223
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-b5a7e7e5c628> in <module>
#       9 # print(ols_results.summary())
#      10 print(ols_results.params)
# ---> 11 print(ols_results.predict(X_test))
#      12 print(ols_model.score)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1036
#    1037         predict_results = self.model.predict(self.params, exog, *args,
# -> 1038                                              **kwargs)
#    1039
#    1040         if exog_index is not None and not hasattr(predict_results,
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in predict(self, params, exog)
#     362             exog = self.exog
#     363
# --> 364         return np.dot(exog, params)
#     365
#     366     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# ValueError: shapes (588,19) and (20,) not aligned: 19 (dim 1) != 20 (dim 0)

# %%
# print('Summary: ', ols_results.summary())
print('Parameters: ', ols_results.params)
print('R2 Adjusted: ', ols_results.rsquared_adj)
print('Confidence Intervals : ', ols_results.conf_int)
print('P-values: ', ols_results.pvalues)

# first is F-statistic and that the second is the p-value
print(sm.stats.linear_rainbow(ols_results))
# result: (0.9050424030857734, 0.9556568644839054)

# to look at all possible methods of results
# dir(ols_results)
# Out:
# Parameters:  const                      -0.000379
# Year                       -0.004029
# Adult_Mortality            -0.268114
# Infant_Deaths               1.228382
# Alcohol                     0.050303
# Percentage_Exp              0.008488
# HepatitisB                 -0.037915
# Measles                    -0.027685
# BMI                         0.093712
# Under_Five_Deaths          -1.245644
# Polio                       0.064613
# Tot_Exp                     0.031546
# Diphtheria                  0.104742
# HIV/AIDS                   -0.249508
# GDP                         0.077874
# Population                  0.000427
# thinness_1to19_years       -0.034066
# thinness_5to9_years        -0.000950
# Income_Comp_Of_Resources    0.133202
# Schooling                   0.216223
# dtype: float64
# R2 Adjusted:  0.8147052518669826
# Confidence Intervals :  <bound method RegressionResults.conf_int of <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021471777088>>
# P-values:  const                        9.660006e-01
# Year                         6.736671e-01
# Adult_Mortality             3.421188e-107
# Infant_Deaths                1.254611e-26
# Alcohol                      1.463899e-05
# Percentage_Exp               6.993926e-01
# HepatitisB                   1.646598e-04
# Measles                      7.148574e-03
# BMI                          2.558413e-15
# Under_Five_Deaths            1.045661e-27
# Polio                        2.148497e-07
# Tot_Exp                      1.222214e-03
# Diphtheria                   4.903931e-15
# HIV/AIDS                    1.750798e-115
# GDP                          6.857970e-04
# Population                   9.679329e-01
# thinness_1to19_years         2.049783e-01
# thinness_5to9_years          9.720553e-01
# Income_Comp_Of_Resources     1.505103e-17
# Schooling                    4.900172e-40
# dtype: float64
# (0.9050424030857734, 0.9556568644839054)
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_data_attr',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'diagn',
#  'eigenvals',
#  'el_test',
#  'ess',
#  'f_pvalue',
#  'f_test',
#  'fittedvalues',
#  'fvalue',
#  'get_influence',
#  'get_prediction',
#  'get_robustcov_results',
#  'initialize',
#  'k_constant',
#  'llf',
#  'load',
#  'model',
#  'mse_model',
#  'mse_resid',
#  'mse_total',
#  'nobs',
#  'normalized_cov_params',
#  'outlier_test',
#  'params',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid',
#  'resid_pearson',
#  'rsquared',
#  'rsquared_adj',
#  'save',
#  'scale',
#  'ssr',
#  'summary',
#  'summary2',
#  't_test',
#  't_test_pairwise',
#  'tvalues',
#  'uncentered_tss',
#  'use_t',
#  'wald_test',
#  'wald_test_terms',
#  'wresid']

# %%
print(elastic_results.summary())
print('\n')
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
'''
print('\n')
print(sqt_lasso_results.summary())
print('\n')
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
'''
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     688.8
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):               0.00
# Time:                        16:08:07   Log-Likelihood:                -8285.3
# No. Observations:                2938   AIC:                         1.661e+04
# Df Residuals:                    2918   BIC:                         1.673e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       89.6011     35.007      2.560      0.011      20.960     158.242
# Year                        -0.0175      0.017     -0.998      0.318      -0.052       0.017
# Adult_Mortality             -0.0203      0.001    -25.491      0.000      -0.022      -0.019
# Infant_Deaths                0.0991      0.008     11.677      0.000       0.082       0.116
# Alcohol                      0.1142      0.025      4.636      0.000       0.066       0.162
# Percentage_Exp            7.134e-05    9.1e-05      0.784      0.433      -0.000       0.000
# HepatitisB                  -0.0154      0.004     -4.116      0.000      -0.023      -0.008
# Measles                  -2.089e-05    7.7e-06     -2.712      0.007    -3.6e-05   -5.79e-06
# BMI                          0.0439      0.005      8.880      0.000       0.034       0.054
# Under_Five_Deaths           -0.0741      0.006    -11.910      0.000      -0.086      -0.062
# Polio                        0.0286      0.004      6.387      0.000       0.020       0.037
# Tot_Exp                      0.0972      0.034      2.835      0.005       0.030       0.164
# Diphtheria                   0.0405      0.005      8.673      0.000       0.031       0.050
# HIV/AIDS                    -0.4737      0.018    -26.668      0.000      -0.509      -0.439
# GDP                       4.807e-05   1.39e-05      3.467      0.001    2.09e-05    7.52e-05
# Population               -3.672e-11    1.7e-09     -0.022      0.983   -3.37e-09    3.29e-09
# thinness_1to19_years        -0.0837      0.051     -1.653      0.098      -0.183       0.016
# thinness_5to9_years          0.0033      0.050      0.067      0.947      -0.095       0.101
# Income_Comp_Of_Resources     5.8889      0.639      9.220      0.000       4.637       7.141
# Schooling                    0.6756      0.042     16.105      0.000       0.593       0.758
# ==============================================================================
# Omnibus:                      138.903   Durbin-Watson:                   0.719
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              402.601
# Skew:                          -0.190   Prob(JB):                     3.77e-88
# Kurtosis:                       4.773   Cond. No.                     2.56e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Parameters:  const                       8.960109e+01
# Year                       -1.745880e-02
# Adult_Mortality            -2.031695e-02
# Infant_Deaths               9.914004e-02
# Alcohol                     1.141960e-01
# Percentage_Exp              7.133959e-05
# HepatitisB                 -1.538398e-02
# Measles                    -2.089060e-05
# BMI                         4.390213e-02
# Under_Five_Deaths          -7.409879e-02
# Polio                       2.860891e-02
# Tot_Exp                     9.720247e-02
# Diphtheria                  4.054365e-02
# HIV/AIDS                   -4.737492e-01
# GDP                         4.806527e-05
# Population                 -3.671864e-11
# thinness_1to19_years       -8.370479e-02
# thinness_5to9_years         3.346593e-03
# Income_Comp_Of_Resources    5.888906e+00
# Schooling                   6.755877e-01
# dtype: float64
# R2:  0.8176756998402106
# "\nprint('\n')\nprint(sqt_lasso_results.summary())\nprint('\n')\nprint('Parameters: ', results.params)\nprint('R2: ', results.rsquared)\n"
