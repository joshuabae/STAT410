# %%
import os

# data frame manipulation and math
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# statistics and statistic models
from scipy import stats
import statsmodels.api as sm

# preprocessing, scoring, ML models
from sklearn import metrics
from sklearn import preprocessing
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# working in the right directory
os.chdir('C:/Users/jsbae/410project/data')

# %%
# load csv data into pandas dataframe
df = pd.DataFrame(pd.read_csv('Life Expectancy Data.csv'))

# %%
# describes the data by providing mean, count, standard deviations, quartiles, etc.
df.describe()
# Out:
#              Year       Status  Life_Expectancy  Adult_Mortality  \
# count  2938.00000  2938.000000      2938.000000      2938.000000
# mean     -0.06016    -0.212389        -0.231071         0.135462
# std       0.57673     0.409069         0.766864         0.811021
# min      -1.00000    -1.000000        -2.887097        -0.934641
# 25%      -0.50000     0.000000        -0.717742        -0.457516
# 50%       0.00000     0.000000         0.000000         0.000000
# 75%       0.50000     0.000000         0.282258         0.542484
# max       0.87500     0.000000         1.362903         3.784314
#
#        Infant_Deaths      Alcohol  Percentage_Exp   HepatitisB      Measles  \
# count    2938.000000  2938.000000     2938.000000  2938.000000  2938.000000
# mean        1.241089     0.125744        1.541353    -0.641277     6.669236
# std         5.360296     0.622778        4.550579     1.642642    31.831430
# ...

# %%
# this lists the percentage of null values that make up each column
print('Percentage of null values for each column:')
print(df.isnull().sum() * 100 / df.isnull().count())

print('\n')
# total count of NaN values for each column
print('NaN count for each column:')
print(len(df) - df.count())
# Out:
# Percentage of null values for each column:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# ...

# %%
# intitial preprocessing steps to rename columns due to inconsistencies, correctly label status for a few countries, fill in NaN
# values with column median, and encode categorical variable 'Status' as 1 for Developed and 0 for Developing

def clean_data(df):
    # renames 
    df.rename(columns={" BMI ":"BMI","Life expectancy ":"Life_Expectancy","Adult Mortality":"Adult_Mortality",
                       "infant deaths":"Infant_Deaths","percentage expenditure":"Percentage_Exp","Hepatitis B":"HepatitisB",
                       "Measles ":"Measles", "under-five deaths ":"Under_Five_Deaths","Diphtheria ":"Diphtheria",
                       " HIV/AIDS":"HIV/AIDS"," thinness  1-19 years":"thinness_1to19_years"," thinness 5-9 years":"thinness_5to9_years","Income composition of resources":"Income_Comp_Of_Resources",
                       "Total expenditure":"Tot_Exp"},inplace=True)   

    # some countries were mislabeled as developing when they are developed countries
    mislabeled_countries = ['Canada', 'Chile', 'Greece', 'Finland', 'France', 'Israel', 'Republic of Korea', 'France', 'Canada']
    
    for country in mislabeled_countries:
        df['Status'].loc[df.Country == country] = 'Developed'
    
    # fill in NaN data with median values of each variable
    df.fillna(df.median(), inplace=True)
    
    # one-hot encode the status variable as 0 for 'Developing' and 1 for 'Developed'
    df['Status'] = preprocessing.LabelEncoder().fit_transform(df['Status'])
    
    # without country name
    df.drop(columns=['Country'], inplace=True)

    return df

# %%
# It seems because of the large difference in scales and units, standardizing is a better transformation for this data set.
def scale_data(df):
    col_names = df.columns
    
    # Create the RobustScaler object (RobustScaler is based on percentiles and hence not easily influenced by outliers)
    # scaling necessary for features to each contribute equally
    scaler = preprocessing.RobustScaler()
    
    # Fit your data on the scaler object
    scaled_df = scaler.fit_transform(df)
    
    scaled_df = pd.DataFrame(scaled_df, columns=col_names)
    return scaled_df

# %%
df = scale_data(clean_data(df))
# Out:
# C:\Users\jsbae\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# NaN values have been taken care of
df.head()
# Out:
#     Year  Status  Life_Expectancy  Adult_Mortality  Infant_Deaths  Alcohol  \
# 0  0.875     0.0        -0.572581         0.777778       2.681818 -0.59468
# 1  0.750     0.0        -0.983871         0.830065       2.772727 -0.59468
# 2  0.625     0.0        -0.983871         0.810458       2.863636 -0.59468
# 3  0.500     0.0        -1.016129         0.836601       3.000000 -0.59468
# 4  0.375     0.0        -1.040323         0.856209       3.090909 -0.59468
#
#    Percentage_Exp  HepatitisB   Measles       BMI  ...     Polio   Tot_Exp  \
# 0        0.014574   -1.928571  3.156142 -0.664850  ... -4.578947  0.812500
# 1        0.019711   -2.142857  1.318529 -0.678474  ... -1.842105  0.819257
# 2        0.019014   -2.000000  1.146426 -0.692098  ... -1.631579  0.802365
# 3        0.030380   -1.785714  7.689105 -0.705722  ... -1.368421  0.934122
# 4       -0.132347   -1.714286  8.316447 -0.716621  ... -1.315789  0.714527
#
# ...

# %%
# these plot each variable against life _expectancy 
def pairplots(df):
    sns.pairplot(data=df,
                 y_vars=['Life_Expectancy'],
                 x_vars=['Adult_Mortality', 'Infant_Deaths', 'Population', 'Schooling'])
    plt.savefig('scaled_all_demographic.png')

    sns.pairplot(data=df,
                 y_vars=['Life_Expectancy'],
                 x_vars=['HepatitisB', 'Measles', 'Polio', 'Diphtheria', 'HIV/AIDS'])
    plt.savefig('scaled_all_vaccine.png')

    sns.pairplot(data=df,
                 y_vars=['Life_Expectancy'],
                 x_vars=['GDP', 'Tot_Exp', 'Income_Comp_Of_Resources', 'Percentage_Exp'])
    plt.savefig('scaled_all_economic.png')

    sns.pairplot(data=df,
                 y_vars=['Life_Expectancy'],
                 x_vars=['Alcohol', 'thinness_1to19_years', 'thinness_5to9_years', 'Under_Five_Deaths', 'BMI'])
    plt.savefig('scaled_all_others.png')
    
pairplots(df)

# %%
"""
From the graphs, I notice a few variables that stand out:
Negatively correlated: Adult Mortality, deaths, HIV/AIDS, thinness (both), under five deaths
Positively correlated: Schooling, GDP (similar to percentage_exp), income composition of resources, BMI, alcohol
"""
# Out:
#                Year        Status  Life_Expectancy  Adult_Mortality  \
# count  1.871000e+03  1.871000e+03     1.871000e+03     1.871000e+03
# mean   1.106948e-14 -1.151226e-15    -1.644863e-16    -3.607780e-17
# std    1.000267e+00  1.000267e+00     1.000267e+00     1.000267e+00
# min   -1.650916e+00 -2.684426e+00    -3.278470e+00    -1.591072e+00
# 25%   -7.970492e-01  3.725192e-01    -5.982316e-01    -7.357201e-01
# 50%    5.681799e-02  3.725192e-01     3.040268e-01    -7.855954e-02
# 75%    9.106852e-01  3.725192e-01     6.490079e-01     6.620500e-01
# max    1.551086e+00  3.725192e-01     2.387182e+00     2.706549e+00
#
#        Infant_Deaths       Alcohol  Percentage_Exp    HepatitisB  \
# count   1.871000e+03  1.871000e+03    1.871000e+03  1.871000e+03
# mean    2.619201e-16  1.789055e-16    2.088121e-16 -3.234837e-16
# std     1.000267e+00  1.000267e+00    1.000267e+00  1.000267e+00
# min    -6.247994e-01 -1.180426e+00   -5.884675e-01 -3.615773e+00
# ...

# %%
# these plot the distributions of each variable after cleaning and scaling

def dist_plots(df):
    columns = df.drop(columns=['Status']).columns
    for column, i in zip(columns,range(len(columns))):
        plt.subplot(5,4,i+1)
        sns.distplot(df[column])
        sns.set(rc={'figure.figsize':(18,18)})
    plt.savefig('distplot.png')

dist_plots(df)

# %%
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a
# way that facilitates comparisons between variables or across levels of a categorical variable.
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the
# distribution, except for points that are determined to be “outliers” using a method that is a
# function of the inter-quartile range.

plt.figure(figsize=(12, 8))
sns.boxplot(data=df, orient='h')
plt.savefig('boxplot_standard_scale.png')

# %%
# Analysis of Variance overcomes the problems associated with multiple t-tests which occur when there are many predictor variables
# We could carry out a separate t-test for each pair of groups, but when you conduct many tests you increase the chances of false positives.


def partial_f_test(df):
    variables = list()
    for column in df.drop(columns=['Life_Expectancy']).columns:
        statistic, pval = stats.f_oneway(df[column], df['Life_Expectancy'])
        variables.append([column, pval])
    return sorted(variables, key=lambda x: x[1])


def full_f_test(df):
    statistic, pval = stats.f_oneway(df['Year'], df['Status'], df['Life_Expectancy'], df['Adult_Mortality'], df['Infant_Deaths'],
       df['Alcohol'], df['Percentage_Exp'], df['HepatitisB'], df['Measles'], df['BMI'],
       df['Under_Five_Deaths'], df['Polio'], df['Tot_Exp'], df['Diphtheria'], df['HIV/AIDS'],
       df['GDP'], df['Population'], df['thinness_1to19_years'], df['thinness_5to9_years'],
       df['Income_Comp_Of_Resources'], df['Schooling'])
    return pval, statistic
    
# partial_f_test(df)
# full_f_test(df)
# Out:
# [['thinness_1to19_years', 1.2323288371732059e-129],
#  ['thinness_5to9_years', 1.2694174294232873e-129],
#  ['GDP', 1.6546340988199242e-112],
#  ['Percentage_Exp', 6.247033540252815e-93],
#  ['Alcohol', 9.924559240607659e-83],
#  ['HIV/AIDS', 2.489080521264461e-79],
#  ['Adult_Mortality', 4.5232608998959924e-69],
#  ['Under_Five_Deaths', 2.5059988922041264e-49],
#  ['Infant_Deaths', 2.7161125064595064e-48],
#  ['Tot_Exp', 8.393717967093808e-44],
#  ['HepatitisB', 3.6410479892725124e-34],
#  ['Diphtheria', 1.8743988342869543e-33],
#  ['Polio', 9.535614073364771e-32],
#  ['Measles', 1.65164719205566e-31],
#  ['Population', 1.3437413626714795e-22],
#  ['Year', 6.824674056853999e-22],
#  ['Schooling', 3.7370453218255037e-13],
#  ['BMI', 1.3170633599452076e-07],
#  ['Income_Comp_Of_Resources', 0.004464607834124608],
#  ['Status', 0.24403929557962747]]

# %%
# Compute pairwise correlation between variables using Kendall correlation
# Spearman correlation is preferred due to its non-assumption of normality

def spearman_correlation(df):
    corr_matrix = df.corr(method='spearman')
    
    print('Spearman Correlation values for each variable:')
    print(corr_matrix['Life_Expectancy'].sort_values(ascending=False))
    print('\n')
    print('Magnitude of Correlation for each variable:')
    print(abs(corr_matrix['Life_Expectancy']).sort_values(ascending=False))
    
    return None

# according to spearman R: 

spearman_correlation(df)

"""
Magnitude of Correlation for each variable:
Life_Expectancy             1.000000
Income_Comp_Of_Resources    0.829403
Schooling                   0.777799
HIV/AIDS                    0.752682
Adult_Mortality             0.650416
Status                      0.639285
Under_Five_Deaths           0.616585
thinness_5to9_years         0.613080
thinness_1to19_years        0.603003
Infant_Deaths               0.598884
GDP                         0.597506
BMI                         0.580386
"""
# Out:
# Spearman Correlation values for each variable:
# Life_Expectancy             1.000000
# Income_Comp_Of_Resources    0.829403
# Schooling                   0.777799
# GDP                         0.597506
# BMI                         0.580386
# Diphtheria                  0.540717
# Polio                       0.531353
# Percentage_Exp              0.427352
# Alcohol                     0.424328
# HepatitisB                  0.297787
# Tot_Exp                     0.283301
# Year                        0.156631
# Population                 -0.071837
# Measles                    -0.280493
# Infant_Deaths              -0.598884
# thinness_1to19_years       -0.603003
# thinness_5to9_years        -0.613080
# Under_Five_Deaths          -0.616585
# Status                     -0.639285
# Adult_Mortality            -0.650416
# HIV/AIDS                   -0.752682
# Name: Life_Expectancy, dtype: float64
#
#
# Magnitude of Correlation for each variable:
# Life_Expectancy             1.000000
# ...

# %%
# this generates the spearman rank correlation matrix
plt.figure(figsize = (20, 15))
sns.heatmap(df.corr(method='spearman'), annot=True)
plt.savefig('predictors_heatmap.png')

# %%
# Univariate linear regression tests. Linear model for testing the individual effect of each of many regressors
# returns F-statistic for each preditor and its p-value

def f_regression_scores(df):
    X = df.drop(columns=['Life_Expectancy'])
    y = df['Life_Expectancy']
    
    F, pval = f_regression(X, y, center=True)
    
    F, pval = sorted(zip(X.columns, F), key=lambda x: x[1]), sorted(zip(X.columns, pval), key=lambda x: x[1])
    return F, pval


F_test, pval = f_regression_scores(df)

# everything besides population is significant

plt.figure(figsize=(20, 8))
plt.scatter([x[0] for x in F_test], [x[1] for x in F_test])
plt.savefig('f-values_for_predictors.png')

# p-values were to difficult to plot because of how small the values were (all too close to 0)

# %%
# Estimate mutual information for a continuous target variable.
# Mutual information between two random variables is a non-negative value,
# which measures the dependency between the variables. It is equal to zero
# if and only if two random variables are independent, and higher values mean higher dependency.

def mutual_information(df):
    X = df.drop(columns=['Life_Expectancy'])
    y = df['Life_Expectancy']
    mi = mutual_info_regression(X, y)
    mi = sorted(zip(X.columns, mi), key=lambda x: x[1])
    return mi

plt.figure(figsize=(20, 8))
mi = mutual_information(df)
print([x[0] for x in mi])

plt.scatter([x[0] for x in mi], [x[1] for x in mi])
plt.savefig('mutual_info.png')
# Out:
# ['Year', 'Measles', 'Population', 'HepatitisB', 'Tot_Exp', 'Diphtheria', 'Percentage_Exp', 'Polio', 'Status', 'Alcohol', 'GDP', 'Under_Five_Deaths', 'Infant_Deaths', 'HIV/AIDS', 'BMI', 'Schooling', 'thinness_5to9_years', 'thinness_1to19_years', 'Income_Comp_Of_Resources', 'Adult_Mortality']

# %%
# defining which variables to drop
# anything with a p-value above 0.05 were taken out of consideration

def ols_feature_selection(df):
    X = df.drop(columns=['Life_Expectancy'])
    y = df['Life_Expectancy']

    X1 = sm.add_constant(X)
    ols = sm.OLS(y, X1)
    lr = ols.fit()

    selected_features = list(X.columns)
    pmax = 1
    while (len(selected_features) > 0):
        p = []
        X_1 = X[selected_features]
        X_1 = sm.add_constant(X_1)
        model = sm.OLS(y, X_1).fit()
        p = pd.Series(model.pvalues.values[1:], index=selected_features)
        pmax = max(p)
        features_with_max_p = p.idxmax()
        if (pmax > 0.05):
            selected_features.remove(features_with_max_p)
            print('Features to be removed:', features_with_max_p, f"(p-value: {pmax})")
        else:
            break
    print('\n')
    print('The selected features are:', selected_features)
    
ols_feature_selection(df)
# Out:
# C:\Users\jsbae\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Features to be removed: Year (p-value: 0.9947731307025895)
# Features to be removed: Population (p-value: 0.9384173842625239)
# Features to be removed: Alcohol (p-value: 0.8630812129885979)
# Features to be removed: Percentage_Exp (p-value: 0.7409402582241615)
# Features to be removed: thinness_5to9_years (p-value: 0.5645582709321281)
# Features to be removed: Tot_Exp (p-value: 0.2962533801767032)
#
#
# The selected features are: ['Status', 'Adult_Mortality', 'Infant_Deaths', 'HepatitisB', 'Measles', 'BMI', 'Under_Five_Deaths', 'Polio', 'Diphtheria', 'HIV/AIDS', 'GDP', 'thinness_1to19_years', 'Income_Comp_Of_Resources', 'Schooling']

# %%
# define variables
drop = ['Life_Expectancy', 'Year', 'Alcohol', 'Percentage_Exp', 'Tot_Exp', 'Population']

X = df.drop(columns=drop)
y = df['Life_Expectancy']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80)

# OLS
linear_model = LinearRegression()
fitted_linear = linear_model.fit(X_train, y_train)

# cross-validation fitted models (ridge, lasso, elastic net)
# Generalized Cross-Validation, which is a form of efficient Leave-One-Out cross-validation

# pick from a wide-range of alphas to control regularization
alphas = np.arange(0.1, 10.1, 0.1)

fitted_cross_ridge = RidgeCV(cv=5, alphas=alphas).fit(X_train, y_train)
fitted_cross_lasso = LassoCV(cv=5, alphas=alphas).fit(X_train, y_train)
fitted_cross_elastic = ElasticNetCV(cv=5, alphas=alphas).fit(X_train, y_train)

results_linear = fitted_linear.predict(X_test)
cross_results_ridge = fitted_cross_ridge.predict(X_test)
cross_results_lasso = fitted_cross_lasso.predict(X_test)
cross_results_elastic = fitted_cross_elastic.predict(X_test)

# %%
print('Weights for each predictor (OLS):\n', fitted_linear.coef_)
print('Weights for each predictor (ridge):\n', fitted_cross_ridge.coef_)
print('Weights for each predictor (lasso):\n', fitted_cross_lasso.coef_)
print('Weights for each predictor (elastic net):\n', fitted_cross_elastic.coef_)

print('\n')

print('Best chosen alpha for each cross-validated model:')
print('Ridge:', fitted_cross_ridge.alpha_)
print('Lasso:', fitted_cross_lasso.alpha_)
print('Elastic Net:', fitted_cross_elastic.alpha_)
# Out:
# Weights for each predictor (OLS):
#  [-0.25236766 -0.23613791  0.18399173 -0.01876623 -0.00048471  0.14380669
#  -0.17537123  0.04718955  0.06075921 -0.02762164  0.01178565 -0.04557524
#   0.01921556  0.10127079  0.19705569]
# Weights for each predictor (ridge):
#  [-0.24235965 -0.23489935  0.17564425 -0.01891717 -0.00050243  0.14115072
#  -0.16746986  0.04760017  0.06145872 -0.02777095  0.01221605 -0.04392483
#   0.01549016  0.1033696   0.19691515]
# Weights for each predictor (lasso):
#  [-0.         -0.11945217 -0.         -0.         -0.00122367  0.
#  -0.00654688  0.02949048  0.04849456 -0.04002547  0.03426991 -0.
#  -0.          0.03223157  0.24284639]
# Weights for each predictor (elastic net):
#  [-0.         -0.17627319 -0.         -0.         -0.00106211  0.01213492
#  -0.00533448  0.04192129  0.05675328 -0.03536927  0.02877375 -0.01800283
#  -0.          0.09998399  0.22214211]
#
#
# Best chosen alpha for each cross-validated model:
# Ridge: 10.0
# Lasso: 0.1
# ...

# %%
# GridSearchCV optimizes parameters with respect to MSE
# running this takes a while...

tuned_parameters = [{'max_depth': [5, 10, 15, 20, 50, 70, 100], 'learning_rate': [0.001, 0.01, 0.1, 0.5], 'n_estimators': [100, 150, 200, 250, 300]}]
MSE_gb = ['mean_squared_error(y_test, y_pred)']

for value in MSE_gb:
    gb_model = GridSearchCV(GradientBoostingRegressor(), tuned_parameters, cv=5)
    gb_model.fit(X_train, y_train)
    y_true, y_pred = y_test, gb_model.predict(X_test)

print('The best hyper-parameters for Gradient Boosting:', gb_model.best_params_)
# Out:
# The best hyper-parameters for Gradient Boosting: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300}

# %%
# GridSearchCV optimizes parameters with respect to MSE
# running this takes a while...

tuned_parameters = [{'max_depth': [5, 10, 15, 20, 50, 70, 100], 'n_estimators': [10, 25, 50, 100, 150, 200, 250]}]
MSE_rf = ['mean_squared_error(y_test, y_pred)']

for value in MSE_rf:
    rf_model = GridSearchCV(RandomForestRegressor(), tuned_parameters, cv=5)
    rf_model.fit(X_train, y_train)
    y_true, y_pred = y_test, rf_model.predict(X_test)

print('The best hyper-parameters for Random Forests:', rf_model.best_params_)
# Out:
# The best hyper-parameters for Random Forests: {'max_depth': 50, 'n_estimators': 200}

# %%
# fit the models with the best hyper parameters you found

rf_model = RandomForestRegressor(n_estimators = 200, max_depth = 50)
rf_model.fit(X_train, y_train)
random_forest_results = rf_model.predict(X_test)

gb_model = GradientBoostingRegressor(n_estimators = 300, max_depth = 5, learning_rate = 0.1)
gb_model.fit(X_train, y_train)
grad_boost_results = gb_model.predict(X_test)

# %%
ols_features = sorted((zip(X.columns, fitted_linear.coef_)), key=lambda x: abs(x[1]), reverse=True)
ridge_features = sorted((zip(X.columns, fitted_cross_ridge.coef_)), key=lambda x: abs(x[1]), reverse=True)
lasso_features = sorted((zip(X.columns, fitted_cross_lasso.coef_)), key=lambda x: abs(x[1]), reverse=True)
elastic_features = sorted((zip(X.columns, fitted_cross_elastic.coef_)), key=lambda x: abs(x[1]), reverse=True)

rf_features = sorted((zip(X.columns, rf_model.feature_importances_)), key=lambda x: x[1], reverse=True)
gb_features = sorted((zip(X.columns, gb_model.feature_importances_)), key=lambda x: x[1], reverse=True)


print('Feature importance ranking (OLS):')
for feature in ols_features:
    print(feature)

print('\n')

print('Feature importance ranking (Ridge):')
for feature in ridge_features:
    print(feature)

print('\n')

print('Feature importance ranking (Lasso):')
for feature in lasso_features:
    print(feature)

print('\n')

print('Feature importance ranking (Elastic Net):')
for feature in elastic_features:
    print(feature)

print('\n')

print('Feature importance ranking (Random Forest):')
for feature in rf_features:
    print(feature)

print('\n')

print('Feature importance ranking (Gradient Boosting):')
for feature in gb_features:
    print(feature)
# Out:
# Feature importance ranking (OLS):
# ('Status', -0.2523676580306723)
# ('Adult_Mortality', -0.23613790974721854)
# ('Schooling', 0.19705568796777387)
# ('Infant_Deaths', 0.183991731670399)
# ('Under_Five_Deaths', -0.17537123278511302)
# ('BMI', 0.14380668654461104)
# ('Income_Comp_Of_Resources', 0.10127079239836302)
# ('Diphtheria', 0.0607592104181346)
# ('Polio', 0.047189551216218976)
# ('thinness_1to19_years', -0.04557524058701824)
# ('HIV/AIDS', -0.02762164241437476)
# ('thinness_5to9_years', 0.019215564695554795)
# ('HepatitisB', -0.01876623282740159)
# ('GDP', 0.01178565446234907)
# ('Measles', -0.0004847059078561062)
#
#
# Feature importance ranking (Ridge):
# ('Status', -0.24235964870265006)
# ('Adult_Mortality', -0.23489934640835525)
# ('Schooling', 0.19691515473833976)
# ('Infant_Deaths', 0.1756442454664313)
# ('Under_Five_Deaths', -0.16746986050667462)
# ('BMI', 0.14115071559665138)
# ('Income_Comp_Of_Resources', 0.10336959892706415)
# ('Diphtheria', 0.06145872054091774)
# ...

# %%
models = ['OLS', 'Ridge', 'Lasso', 'ElasticNet', 'Random Forest', 'Gradient Boosting']
all_results = [results_linear, cross_results_ridge, cross_results_lasso, cross_results_elastic, random_forest_results, grad_boost_results]

def error_metrics(output):
    i = 0
    for result in output:
        print(models[i])
        print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, result))
        print("Mean Squared Error:", metrics.mean_squared_error(y_test, result))
        print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, result)))
        print("Coefficient of Determination R^2:", metrics.r2_score(y_test, result))
        i += 1

error_metrics(all_results)
# Out:
# OLS
# Mean Absolute Error: 0.246392536823719
# Mean Squared Error: 0.10426975145055489
# Root Mean Squared Error: 0.3229082709540821
# Coefficient of Determination R^2: 0.8196182852666581
# Ridge
# Mean Absolute Error: 0.24616249192774542
# Mean Squared Error: 0.10420287658283597
# Root Mean Squared Error: 0.3228047034707456
# Coefficient of Determination R^2: 0.819733975609676
# Lasso
# Mean Absolute Error: 0.30400877857448844
# Mean Squared Error: 0.15485374534947635
# Root Mean Squared Error: 0.3935146062720879
# Coefficient of Determination R^2: 0.7321103797560633
# ElasticNet
# Mean Absolute Error: 0.2735286790428279
# Mean Squared Error: 0.13029301144401473
# Root Mean Squared Error: 0.36096123260540697
# Coefficient of Determination R^2: 0.7745992821975098
# Random Forest
# Mean Absolute Error: 0.09815688775510215
# Mean Squared Error: 0.024222202220020455
# Root Mean Squared Error: 0.15563483613902274
# Coefficient of Determination R^2: 0.9580967412861153
# Gradient Boosting
# ...

# %%
# fitted vs. actual (seems pretty linear)
fig, ([ax1, ax2, ax3], [ax4, ax5, ax6]) = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Correlation Plots (Fitted vs. Actual)')

ax1.set_title('OLS')
ax1.scatter(results_linear, y_test, s=5)
ax1.plot(results_linear, np.poly1d(np.polyfit(results_linear, y_test, 1))((results_linear)), color='blue', linewidth=3)

ax2.set_title('Ridge')
ax2.scatter(cross_results_ridge, y_test, s=5) 
ax2.plot(cross_results_ridge, np.poly1d(np.polyfit(cross_results_ridge, y_test, 1))((cross_results_ridge)), color='blue', linewidth=3)

ax3.set_title('Lasso')
ax3.scatter(cross_results_lasso, y_test, s=5)
ax3.plot(cross_results_lasso, np.poly1d(np.polyfit(cross_results_lasso, y_test, 1))((cross_results_lasso)), color='blue', linewidth=3)

ax4.set_title('Elastic Net')
ax4.scatter(cross_results_elastic, y_test, s=5)
ax4.plot(cross_results_elastic, np.poly1d(np.polyfit(cross_results_elastic, y_test, 1))((cross_results_elastic)), color='blue', linewidth=3)

ax5.set_title('Random Forest')
ax5.scatter(cross_results_elastic, y_test, s=5)
ax5.plot(random_forest_results, np.poly1d(np.polyfit(random_forest_results, y_test, 1))((random_forest_results)), color='blue', linewidth=3)

ax6.set_title('Gradient Boosted')
ax6.scatter(cross_results_elastic, y_test, s=5)
ax6.plot(grad_boost_results, np.poly1d(np.polyfit(grad_boost_results, y_test, 1))((grad_boost_results)), color='blue', linewidth=3)

# fit a best-fit line to each graph and give slope and y-intercept
m1, b1 = np.polyfit(results_linear, y_test, 1)
m2, b2= np.polyfit(cross_results_ridge, y_test, 1)
m3, b3 = np.polyfit(cross_results_lasso, y_test, 1)
m4, b4 = np.polyfit(cross_results_elastic, y_test, 1)
m5, b5 = np.polyfit(random_forest_results, y_test, 1)
m6, b6 = np.polyfit(grad_boost_results, y_test, 1)

print(m1, b1)
print(m2, b2)
print(m3, b3)
print(m4, b4)
print(m5, b5)
print(m6, b6)

"""
slopes and intercept (very close to 1 and 0, respectively)
1.0215778630708172 0.018765683847672826
1.0239109812078506 0.01890252407144225
1.2098174579278107 0.058852831497776266
1.1389077737636337 0.0407225641439753
1.036250985858659 0.001191131636682304
1.026224195215614 -0.003090469106978607
"""

plt.savefig('correlation_plots.png')
# Out:
# 1.0215778630708172 0.018765683847672826
# 1.0239109812078506 0.01890252407144225
# 1.2098174579278107 0.058852831497776266
# 1.1389077737636337 0.0407225641439753
# 1.036250985858659 0.001191131636682304
# 1.026224195215614 -0.003090469106978607

# %%
# residuals vs. fitted

linear_residuals = y_test - results_linear
cross_ridge_residuals = y_test - cross_results_ridge
cross_lasso_residuals = y_test - cross_results_lasso
cross_elastic_residuals = y_test - cross_results_elastic
rf_residuals = y_test - random_forest_results
gb_residuals = y_test - grad_boost_results

fig, ([ax1, ax2, ax3], [ax4, ax5, ax6]) = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Residuals Plots')

ax1.set_title('OLS')
ax1.scatter(results_linear, linear_residuals, s=5)
ax1.plot(results_linear, np.poly1d(np.polyfit(results_linear, linear_residuals, 1))(results_linear), color='blue', linewidth=3)

ax2.set_title('Ridge')
ax2.scatter(cross_results_ridge, cross_ridge_residuals, s=5) 
ax2.plot(cross_results_ridge, np.poly1d(np.polyfit(cross_results_ridge, cross_ridge_residuals, 1))(cross_results_ridge), color='blue', linewidth=3)

ax3.set_title('Lasso')
ax3.scatter(cross_results_lasso, cross_lasso_residuals, s=5) 
ax3.plot(cross_results_lasso, np.poly1d(np.polyfit(cross_results_lasso, cross_lasso_residuals, 1))(cross_results_lasso), color='blue', linewidth=3)

ax4.set_title('Elastic Net')
ax4.scatter(cross_results_elastic, cross_elastic_residuals, s=5)
ax4.plot(cross_results_elastic, np.poly1d(np.polyfit(cross_results_elastic, cross_elastic_residuals, 1))(cross_results_elastic), color='blue', linewidth=3)

ax5.set_title('Random Forest')
ax5.scatter(random_forest_results, rf_residuals, s=5)
ax5.plot(random_forest_results, np.poly1d(np.polyfit(random_forest_results, rf_residuals, 1))((random_forest_results)), color='blue', linewidth=3)

ax6.set_title('Gradient Boosted')
ax6.scatter(grad_boost_results, gb_residuals, s=5)
ax6.plot(grad_boost_results, np.poly1d(np.polyfit(grad_boost_results, gb_residuals, 1))((grad_boost_results)), color='blue', linewidth=3)

# plt.show()
plt.savefig('residual_plot.png')

m1, b1 = np.polyfit(results_linear, linear_residuals, 1)
m2, b2= np.polyfit(cross_results_ridge, cross_ridge_residuals, 1)
m3, b3 = np.polyfit(cross_results_lasso, cross_lasso_residuals, 1)
m4, b4 = np.polyfit(cross_results_elastic, cross_elastic_residuals, 1)
m5, b5 = np.polyfit(random_forest_results, rf_residuals, 1)
m6, b6 = np.polyfit(grad_boost_results, gb_residuals, 1)

print(m1, b1)
print(m2, b2)
print(m3, b3)
print(m4, b4)
print(m5, b5)
print(m6, b6)


"""
Slopes are very close to 0
0.02157786307081674 0.01876568384767276
0.02391098120785052 0.018902524071442297
0.20981745792781062 0.05885283149777632
0.138907773763634 0.040722564143975216
0.03625098585865832 0.0011911316366822354
0.026224195215614463 -0.003090469106978543
"""
# Out:
# 0.02157786307081674 0.01876568384767276
# 0.02391098120785052 0.018902524071442297
# 0.20981745792781062 0.05885283149777632
# 0.138907773763634 0.040722564143975216
# 0.03625098585865832 0.0011911316366822354
# 0.026224195215614463 -0.003090469106978543
# '\nSlopes are very close to 0\n0.02157786307081674 0.01876568384767276\n0.02391098120785052 0.018902524071442297\n0.20981745792781062 0.05885283149777632\n0.138907773763634 0.040722564143975216\n0.03625098585865832 0.0011911316366822354\n0.026224195215614463 -0.003090469106978543\n'

# %%
fig, ([ax1, ax2, ax3], [ax4, ax5, ax6]) = plt.subplots(2, 3, figsize=(25, 15))
fig.suptitle('QQ-plots')

ax1 = plt.subplot(231)
stats.probplot(linear_residuals, plot=plt)

ax2 = plt.subplot(232)
stats.probplot(cross_ridge_residuals, plot=plt)

ax3 = plt.subplot(233)
stats.probplot(cross_lasso_residuals, plot=plt)

ax4 = plt.subplot(234)
stats.probplot(cross_elastic_residuals, plot=plt)

ax5 = plt.subplot(235)
stats.probplot(rf_residuals, plot=plt)

ax6 = plt.subplot(236)
stats.probplot(gb_residuals, plot=plt)


# departures from linearity provide evidence of non-normality
plt.savefig('qq_plot.png')
